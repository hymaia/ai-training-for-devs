# %% [markdown]
# # 🤖 Agentic RAG Tutorial
#
# Welcome! In this notebook, you'll learn how to build an **Agentic Retrieval-Augmented Generation (RAG)** system.
#
# ## 📚 What You'll Learn
# - How to set up a vector store for document retrieval
# - How to create a retrieval tool
# - How to build an AI agent that can search documents intelligently
# - How to integrate everything into an interactive chatbot
#
# ---

# %% [markdown]
# ## 📦 Step 1: Import Required Libraries
#
# First, let's import all the tools we need for our RAG system.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv
from langchain_core.documents import Document
from langchain_core.messages.base import BaseMessage
from langchain.messages import HumanMessage, AIMessage
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import FastEmbedSparse, QdrantVectorStore, RetrievalMode
from langfuse import Langfuse
from qdrant_client import QdrantClient
from typing import Optional
import gradio as gr

# %% [markdown]
# ## ⚙️ Step 2: Configure Your Model
#
# Here we set up the key parameters for our AI model. **Don't change these values!**

# %%
# 🎯 Model Configuration (DO NOT MODIFY)
MODEL_NAME = "gpt-5-nano"
REASONING_EFFORT = "minimal"  # "minimal" | "low" | "medium" | "high"
TEMPERATURE = 0
K_RETRIEVAL = 4

# %% [markdown]
# ## 🔧 Step 3: Helper Functions
#
# These functions help us:
# - Connect to Langfuse for observability
# - Load our vector database
# - Format documents for display

# %%
def create_langfuse_client() -> Langfuse:
    """Initialize Langfuse for observability tracking."""
    load_dotenv()
    return Langfuse(
        public_key=os.environ["LANGFUSE_PUBLIC_KEY"],
        secret_key=os.environ["LANGFUSE_SECRET_KEY"],
        host=os.environ["LANGFUSE_BASE_URL"],
    )


def load_vector_store(path_to_vector_store: Optional[Path] = None):
    """Load the vector database containing FAQ documents."""
    sparse_embeddings = FastEmbedSparse(model_name="Qdrant/bm25")
    load_dotenv()

    this_dir = Path.cwd().parent
    path_to_vector_store = path_to_vector_store or this_dir / "vector_store"

    print(f"📂 Loading vector store from: {path_to_vector_store}")

    embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

    # Remove lock file if exists
    lock_file = path_to_vector_store / ".lock"
    if lock_file.exists():
        os.remove(lock_file)

    client = QdrantClient(path=path_to_vector_store)
    return QdrantVectorStore(
        client=client,
        collection_name="faq_collection",
        embedding=embeddings,
        sparse_embedding=sparse_embeddings,
        vector_name="dense",
        sparse_vector_name="sparse",
        retrieval_mode=RetrievalMode.HYBRID,
    )


def format_docs_alternative(docs: list[Document]):
    """Format retrieved documents for the prompt."""
    formatted = []
    for i, doc in enumerate(docs, 1):
        formatted.append(
            f"Document {i}:\n{doc.metadata['faq_body']}\nSource: {doc.metadata['faq_id']}"
        )
    return "\n\n".join(formatted)

# %% [markdown]
# ---
#
# ## 🎯 YOUR TASK: Create a Retrieval Tool (adapt what we had but for using with langChain Agents)
#
# ### 📖 Instructions
#
# Your goal is to implement a `retrieve_context` tool that:
# 1. Takes a user query as input
# 2. Searches the vector store for relevant documents
# 3. Returns formatted results
#
# ### 📚 Documentation
# Refer to: [LangChain RAG Documentation](https://docs.langchain.com/oss/python/langchain/rag)
#
# ### 💡 Hint
# Use the `@tool` decorator with `response_format="content_and_artifact"`

# %%
from langchain.tools import tool

load_dotenv()

# 📂 Set up paths
notebook_dir = Path.cwd()
PATH_TO_VECTOR_STORE = notebook_dir.parent / "5_Evaluation" / "vector_store"

vector_store = load_vector_store(path_to_vector_store=PATH_TO_VECTOR_STORE)


@tool(response_format="content_and_artifact")
def retrieve_context(query: str, k: int = K_RETRIEVAL):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=k)
    serialized = format_docs_alternative(retrieved_docs)
    return serialized, retrieved_docs
# Out:
# 📂 Loading vector store from: /Users/aniszakari/Documents/ai-training-for-devs/5_Evaluation/vector_store

# %% [markdown]
# ### 🧪 Test Your Retrieval Tool
#
# Let's verify that the retrieval tool works correctly!

# %%
# Test the retrieve_context function ( you can comment the @tool decorator if you want to test the code)
serialized, retrieved_docs = retrieve_context(query="How do I post an ad?")
print("✅ Retrieval test successful!")
print(f"Retrieved {len(retrieved_docs)} documents")

# %% [markdown]
# ---
#
# ## 🤖 YOUR TASK: Build the Agentic RAG System
#
# ### 📖 Instructions
#
# Now create an agent that:
# 1. Uses the `retrieve_context` tool
# 2. Follows specific instructions for answering questions
# 3. Only provides information from retrieved documents
#
# ### 📚 Documentation
# Follow: [LangChain Agentic RAG Guide](https://docs.langchain.com/oss/python/langchain/rag)
#
# ### ✅ Solution (Uncomment to see)

# %%
# ============================================
# SOLUTION: Create the Agent
# ============================================

from langchain.agents import create_agent

model = ChatOpenAI(model=MODEL_NAME, temperature=TEMPERATURE)
tools = [retrieve_context]

# Define the system prompt
prompt = """\
You are a helpful assistant answering questions about customer care for AI-Bay.

Use the context documents to answer the user's question. If the answer is not in the provided documents, say "I don't have that information in the provided documents."

Instructions:
1. Answer based ONLY on the provided documents
2. Be specific and cite which document(s) you used
3. If information is unclear or missing, say so
4. Keep answers concise but complete
5. Use a friendly, informative tone
"""

agent = create_agent(model, tools, system_prompt=prompt)

# %% [markdown]
# ---
#
# ## 🧪 Test the Agent
#
# ### Test 1: Stream Response

# %%
query = """The person who bought my item received a notification saying their package was available, 
but when they went to the pickup point, the order couldn't be found. Will I still get paid?"""

print("🔄 Streaming response...\n")
for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# 🔄 Streaming response...
#
# ================================ Human Message =================================
#
# The person who bought my item received a notification saying their package was available,
# but when they went to the pickup point, the order couldn't be found. Will I still get paid?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_tKEeYf34bb1XhbH10qmsuU6I)
#  Call ID: call_tKEeYf34bb1XhbH10qmsuU6I
#   Args:
#     query: seller asks about payment if pickup point cannot locate order; whether payment is guaranteed when notification says package available but couldn't be found at pickup point
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Document 1:
# Delivery by Colissimo
# If an issue occurs during the delivery of your parcel with Colissimo (such as tracking problems, damaged parcel or item, etc.), we invite you to contact Colissimo Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Mondial Relay
# If an issue occurs during the delivery of your parcel with Mondial Relay (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Mondial Relay Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Shop2Shop by Chronopost
# If an issue occurs during the delivery of your parcel with Shop2Shop by Chronopost (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Shop2Shop by Chronopost Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Relais Colis
# If an issue occurs during the delivery of your parcel with Relais Colis (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Relais Colis Customer Service to take the necessary steps.
#
# Delivery by another carrier
# If an issue occurs during delivery with another carrier, please contact the Customer Service of the relevant delivery provider as soon as possible, then inform the buyer.
# Examples of carriers:
#
# Chronopost
# By phone: 09 69 39 13 91 (standard rate call)
# Monday to Friday: 8 a.m. – 7 p.m.
# Saturday: 8 a.m. – 12 p.m.
# FAQ available online.
#
# UPS
# By phone: 0 173 006 661 (standard rate call)
# Monday to Friday: 8 a.m. – 7 p.m.
# Saturday: 8 a.m. – 1 p.m.
# Online support or via a Virtual Assistant and FAQ.
#
# Good to know
# If your buyer has not confirmed receipt of the parcel, we encourage you to contact them again via AI-Bay messaging.
#
# You will receive your payment directly into your AI-Bay wallet (on average within 6 business days after the payment is triggered).
# Source: 360011708540
#
# Document 2:
# **Package Tracking Is Stuck**
# **The Package Is Marked as Delivered but Not Available at the Pickup Point**
# **The Buyer Has Not Confirmed Receipt of the Package**
# **The Buyer Reports the Item Is Damaged or Not as Ordered**
# **The Package Is Reported as Damaged or Lost**
#
# ---
#
# **Note:** If you chose home delivery with your own carrier, please make sure to share all relevant details (carrier name, tracking number) with your buyer.
#
# ---
#
# ### Package Tracking Is Stuck
# If tracking has been stuck for more than 5 days (excluding Saturday, Sunday, and Monday), you should:
#
# - Contact Shop2Shop by Chronopost via the online form, chatbot, or by phone at **09 69 391 391** (toll-free), Monday to Friday from 8 a.m. to 7 p.m., and Saturday from 8 a.m. to 12 p.m.
# - Shop2Shop by Chronopost will have up to 10 days to carry out the necessary checks.
# - If the package has not been located between the 6th and 10th day after shipment, ask your buyer to contact **AI-Bay Customer Service** through their messaging system.
#
# ---
#
# ### The Package Is Marked as Delivered but Not Available at the Pickup Point
# Once the issue has been confirmed, we will ask your buyer to:
#
# - Report the issue or damage to the pickup location.
# - Contact **AI-Bay Customer Service** through their messaging system.
#
# ---
#
# ### The Buyer Has Not Confirmed Receipt of the Package
# If your buyer has not confirmed receipt, we encourage you to contact them again via **AI-Bay messaging**.
# If the buyer does not confirm receipt within 15 days after shipment confirmation, or if they have not requested assistance, the payment will be automatically released.
# You will receive the funds directly in your **AI-Bay wallet** (usually within 24 hours, excluding weekends and holidays).
#
# ---
#
# ### The Buyer Reports the Item Is Damaged or Not as Ordered
# The buyer must check the condition of the package at the pickup point.
# If there is any issue, they must immediately make a note of it and/or refuse the package with the store clerk.
# They should also contact our support team to temporarily suspend the transaction.
#
# ---
#
# ### The Package Is Reported as Damaged or Lost
# Once the issue has been confirmed, we will ask your buyer to:
#
# - Contact **AI-Bay Customer Service** through their messaging system.
# Source: 10795165349138
#
# Document 3:
# **Package Tracking Is Stuck**
# **The Package Is Marked as Delivered but Not Available at the Pickup Point**
# **The Buyer Has Not Confirmed Receipt of the Package**
# **The Buyer Reports the Item Is Damaged or Not as Ordered**
# **The Package Is Reported as Damaged or Lost**
#
# ---
#
# **Note:** If you chose home delivery with your own carrier, please make sure to share all relevant details (carrier name, tracking number) with your buyer.
#
# ---
#
# ### Package Tracking Is Stuck
# If tracking has been stuck for more than 5 days (excluding Saturday, Sunday, and Monday), you should:
#
# - Contact Shop2Shop by Chronopost via the online form, chatbot, or by phone at **09 69 391 391** (toll-free), Monday to Friday from 8 a.m. to 7 p.m., and Saturday from 8 a.m. to 12 p.m.
# - Shop2Shop by Chronopost will have up to 10 days to carry out the necessary checks.
# - If the package has not been located between the 6th and 10th day after shipment, ask your buyer to contact **AI-Bay Customer Service** through their messaging system.
#
# ---
#
# ### The Package Is Marked as Delivered but Not Available at the Pickup Point
# Once the issue has been confirmed, we will ask your buyer to:
#
# - Report the issue or damage to the pickup location.
# - Contact **AI-Bay Customer Service** through their messaging system.
#
# ---
#
# ### The Buyer Has Not Confirmed Receipt of the Package
# If your buyer has not confirmed receipt, we encourage you to contact them again via **AI-Bay messaging**.
# If the buyer does not confirm receipt within 15 days after shipment confirmation, or if they have not requested assistance, the payment will be automatically released.
# You will receive the funds directly in your **AI-Bay wallet** (usually within 24 hours, excluding weekends and holidays).
#
# ---
#
# ### The Buyer Reports the Item Is Damaged or Not as Ordered
# The buyer must check the condition of the package at the pickup point.
# If there is any issue, they must immediately make a note of it and/or refuse the package with the store clerk.
# They should also contact our support team to temporarily suspend the transaction.
#
# ---
#
# ### The Package Is Reported as Damaged or Lost
# Once the issue has been confirmed, we will ask your buyer to:
#
# - Contact **AI-Bay Customer Service** through their messaging system.
# Source: 10795165349138
#
# Document 4:
# Delivery by Colissimo
# If an issue occurs during the delivery of your parcel with Colissimo (such as tracking problems, damaged parcel or item, etc.), we invite you to contact Colissimo Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Mondial Relay
# If an issue occurs during the delivery of your parcel with Mondial Relay (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Mondial Relay Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Shop2Shop by Chronopost
# If an issue occurs during the delivery of your parcel with Shop2Shop by Chronopost (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Shop2Shop by Chronopost Customer Service to take the necessary steps.
# Learn more.
#
# Delivery by Relais Colis
# If an issue occurs during the delivery of your parcel with Relais Colis (parcel marked as delivered but unavailable, tracking stuck, etc.), please contact Relais Colis Customer Service to take the necessary steps.
#
# Delivery by another carrier
# If an issue occurs during delivery with another carrier, please contact the Customer Service of the relevant delivery provider as soon as possible, then inform the buyer.
# Examples of carriers:
#
# Chronopost
# By phone: 09 69 39 13 91 (standard rate call)
# Monday to Friday: 8 a.m. – 7 p.m.
# Saturday: 8 a.m. – 12 p.m.
# FAQ available online.
#
# UPS
# By phone: 0 173 006 661 (standard rate call)
# Monday to Friday: 8 a.m. – 7 p.m.
# Saturday: 8 a.m. – 1 p.m.
# Online support or via a Virtual Assistant and FAQ.
#
# Good to know
# If your buyer has not confirmed receipt of the parcel, we encourage you to contact them again via AI-Bay messaging.
#
# You will receive your payment directly into your AI-Bay wallet (on average within 6 business days after the payment is triggered).
# Source: 360011708540
# ================================== Ai Message ==================================
#
# I don’t have explicit guidance in the provided documents about whether you’ll still get paid in this exact situation (package marked delivered but not found at the pickup point).
#
# What the docs do say:
# - For a delivery marked as delivered but not available at the pickup point, AI-Bay asks the buyer to report the issue to the pickup location and to contact AI-Bay Customer Service (Documents 2 and 3).
# - If the buyer has not confirmed receipt within 15 days after shipment confirmation (or hasn’t requested assistance), the payment is automatically released to you and appears in your AI-Bay wallet (Documents 2 and 3). Average timing is listed as within 24 hours after release, excluding weekends/holidays.
# - For ongoing issues, you’re advised to coordinate via AI-Bay messaging and have the buyer and carrier/ pickup point involved (Documents 2, 3, and 4).
#
# Next steps:
# - Encourage the buyer to report the issue to the pickup location and contact AI-Bay Customer Service.
# - Stay in touch with the buyer via AI-Bay messaging.
# - If the buyer does not confirm receipt within 15 days after shipment, the payment will auto-release to you per the documents.
#
# If you’d like, I can pull out the exact steps to take next or guide you through what to tell the buyer. The core payment rule in these cases is the automatic release after 15 days if there’s no receipt confirmation or assistance requested by the buyer.

# %% [markdown]
# ### Test 2: Get Complete Response and observe the nature of the output

# %%
output = agent.invoke({"messages": [{"role": "user", "content": query}]})

# %% [markdown]
# ### Adapt the rag_assistant_response code below consequently
# ### if you want to add the tracing with langfuse see [here](https://langfuse.com/integrations/frameworks/langchain) (callbackhandler)

# %% [markdown]
# ---
#
# ## 🎨 Build an Interactive Chat Interface
#
# ### 🔍 Optional: Add Langfuse Tracing
#
# Langfuse helps you monitor and debug your RAG system. Learn more: [Langfuse Integration](https://langfuse.com/integrations/frameworks/langchain)
#
# ### 💬 Create the Chat Function

# %%
from langfuse import get_client
from langfuse.langchain import CallbackHandler


# Initialize Langfuse CallbackHandler for Langchain (tracing)
langfuse_handler = CallbackHandler()


def rag_assistant_response(message, history):
    """Handle chat messages from Gradio interface."""
    output = agent.invoke(
        {"messages": [{"role": "user", "content": message}]},
        config={"callbacks": [langfuse_handler]},
    )
    return output["messages"][-1].content

    # for event in agent.stream({"messages": [{"role": "user", "content": message}]},stream_mode="values"):
    #     yield event["messages"][-1].content

# %% [markdown]
# ### 🚀 Launch the Interactive Chat

# %%
# Launch interactive chat
demo = gr.ChatInterface(
    fn=rag_assistant_response,
    title="🤖 AI-Bay Customer Support Assistant",
    description="Ask me anything about AI-Bay! Powered by Langfuse prompt management.",
    examples=[
        "How do I post an ad?",
        "How can I contact a seller?",
        "Where can I see my messages?",
        "What are the posting guidelines?",
    ],
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ---
#
# ## 🎓 Next Steps
#
# ### Challenge: Integrate with Evaluation
#
# Now that you have a working agentic RAG system, try integrating it with the evaluation framework from Exercise 5!
#
# This will help you:
# - Measure the quality of your agent's responses
# - Compare different configurations
# - Identify areas for improvement
#
# ### 💡 Tips
# - Use the same evaluation metrics
# - Test with various query types
# - Monitor performance with Langfuse
#
# ---
#
# ## 📚 Additional Resources
#
# - [LangChain RAG Documentation](https://docs.langchain.com/oss/python/langchain/rag)
# - [Langfuse Tracing Guide](https://langfuse.com/integrations/frameworks/langchain)
# - [Gradio Documentation](https://www.gradio.app/docs)
#
# ---
#
# **Great job! You've built a complete agentic RAG system! 🎉**
